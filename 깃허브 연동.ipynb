# %%
# 연동 과정1: 드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 연동 과정2: 기본 작업 위치 변경
# %cd /content/drive/MyDrive/빅데이터분석기사_실기
# Out:
# /content/drive/MyDrive/빅데이터분석기사_실기

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# 연동 과정3: 깃허브 정보 연동
# !git config --global user.email "lucid9dawn@gmail.com"
# !git config --global user.name "bbang-jun"

# %%
# 연동 과정4: 기본 작업 위치에 레포 클론
# !git clone https://{개인 액세스 토큰}@github.com/bbang-jun/Big-Data-Analysis-Engineer-Practical-Test.git
# Out:
# Cloning into 'Big-Data-Analysis-Engineer-Practical-Test'...
# warning: You appear to have cloned an empty repository.

# %%
# !git config --global user.email "lucid9dawn@gmail.com"
# !git config --global user.name "bbang-jun

# 해당 폴더로 이동
# %cd /content/drive/MyDrive/빅데이터분석기사_실기/Big-Data-Analysis-Engineer-Practical-Test/

# 변경사항 스테이징 및 커밋
# !git add .
# !git commit -m "작업형1 Section 02"

# 깃허브로 전송
# !git push origin main
# Out:
# /bin/bash: -c: line 1: unexpected EOF while looking for matching `"'
# /bin/bash: -c: line 2: syntax error: unexpected end of file
# /content/drive/MyDrive/빅데이터분석기사_실기/Big-Data-Analysis-Engineer-Practical-Test
# [main 9448381] 작업형1 Section 02
#  2 files changed, 2 insertions(+), 2 deletions(-)
#  rewrite "\341\204\214\341\205\241\341\206\250\341\204\213\341\205\245\341\206\270\341\204\222\341\205\247\341\206\2741/\341\204\214\341\205\241\341\206\250\341\204\213\341\205\245\341\206\270\341\204\222\341\205\247\341\206\2741_\341\204\213\341\205\247\341\206\253\341\204\211\341\205\263\341\206\270\341\204\206\341\205\256\341\206\253\341\204\214\341\205\246.ipynb" (93%)
# Enumerating objects: 9, done.
# Counting objects: 100% (9/9), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 4.26 KiB | 242.00 KiB/s, done.
# Total 5 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/bbang-jun/Big-Data-Analysis-Engineer-Practical-Test.git
#    cba7fb0..9448381  main -> main
