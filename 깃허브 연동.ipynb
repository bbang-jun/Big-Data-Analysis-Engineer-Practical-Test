# %%
# 연동 과정1: 드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 연동 과정2: 기본 작업 위치 변경
# %cd /content/drive/MyDrive/빅데이터분석기사_실기
# Out:
# /content/drive/MyDrive/빅데이터분석기사_실기

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# 연동 과정3: 깃허브 정보 연동
# !git config --global user.email "lucid9dawn@gmail.com"
# !git config --global user.name "bbang-jun"

# %%
# 연동 과정4: 기본 작업 위치에 레포 클론
# !git clone https://{개인 액세스 토큰}@github.com/bbang-jun/Big-Data-Analysis-Engineer-Practical-Test.git
# Out:
# Cloning into 'Big-Data-Analysis-Engineer-Practical-Test'...
# ...

# %%
# !git config --global user.email "lucid9dawn@gmail.com"
# !git config --global user.name "bbang-jun

# 해당 폴더로 이동
# %cd /content/drive/MyDrive/빅데이터분석기사_실기/Big-Data-Analysis-Engineer-Practical-Test/

# 변경사항 스테이징 및 커밋
# !git add .
# !git commit -m "07.인덱싱/슬라이싱(loc), 08.인덱싱/슬라이싱(iloc), 09.데이터 추가/변경"

# 깃허브로 전송
# !git push origin main
# Out:
# /bin/bash: -c: line 1: unexpected EOF while looking for matching `"'
# /bin/bash: -c: line 2: syntax error: unexpected end of file
# /content/drive/MyDrive/빅데이터분석기사_실기/Big-Data-Analysis-Engineer-Practical-Test
# [main 2815666] 06.데이터 삭제
#  3 files changed, 3 insertions(+), 1 deletion(-)
#  create mode 100644 "pandas/08.\341\204\213\341\205\265\341\206\253\341\204\203\341\205\246\341\206\250\341\204\211\341\205\265\341\206\274 \341\204\211\341\205\263\341\206\257\341\204\205\341\205\241\341\204\213\341\205\265\341\204\211\341\205\265\341\206\274(iloc).ipynb"
#  create mode 100644 "pandas/09.\341\204\203\341\205\246\341\204\213\341\205\265\341\204\220\341\205\245 \341\204\216\341\205\256\341\204\200\341\205\241 \341\204\207\341\205\247\341\206\253\341\204\200\341\205\247\341\206\274.ipynb"
# Enumerating objects: 9, done.
# Counting objects: 100% (9/9), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (6/6), done.
# ...
