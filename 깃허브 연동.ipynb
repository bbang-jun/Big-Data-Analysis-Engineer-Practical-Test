# %%
# 연동 과정1: 드라이브 마운트
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 연동 과정2: 기본 작업 위치 변경
# %cd /content/drive/MyDrive/빅데이터분석기사_실기
# Out:
# /content/drive/MyDrive/빅데이터분석기사_실기

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# 연동 과정3: 깃허브 정보 연동
# !git config --global user.email "lucid9dawn@gmail.com"
# !git config --global user.name "bbang-jun"

# %%
# 연동 과정4: 기본 작업 위치에 레포 클론
# !git clone https://{개인 액세스 토큰}@github.com/bbang-jun/Big-Data-Analysis-Engineer-Practical-Test.git
# Out:
# Cloning into 'Big-Data-Analysis-Engineer-Practical-Test'...
# warning: You appear to have cloned an empty repository.

# %%
# !git config --global user.email "lucid9dawn@gmail.com"
# !git config --global user.name "bbang-jun

# 해당 폴더로 이동
# %cd /content/drive/MyDrive/빅데이터분석기사_실기/Big-Data-Analysis-Engineer-Practical-Test/

# 변경사항 스테이징 및 커밋
# !git add .
# !git commit -m "02.데이터 저장 및 불러오기"

# 깃허브로 전송
# !git push origin main
# Out:
# /content/drive/MyDrive/빅데이터분석기사_실기/Big-Data-Analysis-Engineer-Practical-Test
# [main e5a28b0] 01.데이터프레임과 시리즈
#  3 files changed, 3 insertions(+), 1 deletion(-)
#  create mode 100644 "pandas/\341\204\221\341\205\241\341\206\253\341\204\203\341\205\241\341\204\211\341\205\263_\341\204\216\341\205\265\341\204\220\341\205\263\341\204\211\341\205\265\341\204\220\341\205\263.ipynb"
#  rewrite "\341\204\200\341\205\265\341\206\272\341\204\222\341\205\245\341\204\207\341\205\263 \341\204\213\341\205\247\341\206\253\341\204\203\341\205\251\341\206\274.ipynb" (88%)
# Enumerating objects: 10, done.
# Counting objects: 100% (10/10), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (6/6), 5.31 KiB | 388.00 KiB/s, done.
# Total 6 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/bbang-jun/Big-Data-Analysis-Engineer-Practical-Test.git
#    db0e221..e5a28b0  main -> main
